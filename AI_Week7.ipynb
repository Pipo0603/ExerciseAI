# %% [markdown]
# <a href="https://colab.research.google.com/github/Pipo0603/ExerciseAI/blob/main/AI_Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url = '/content/1.01. Simple linear regression.csv'
data = pd.read_csv(url)
data.head(21)
x1=np.array(data['SAT'])
y=np.array(data['GPA'])
np.reshape(-1,1)
regression_model = linear_model.LinearRegression()
regression_model.fit(x1,y)
print(regression_model.intercept_)
print(regression_model.coef)


plt.scatter(x1,y);
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()
data.hist()
correlation = data.corr()
print(correlation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a9679f00e2b5> in <module>
#      11 np.reshape(-1,1)
#      12 regression_model = linear_model.LinearRegression()
# ---> 13 regression_model.fit(x1,y)
#      14 print(regression_model.intercept_)
#      15 print(regression_model.coef)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1104         )
#    1105
# -> 1106     X = check_array(
#    1107         X,
#    1108         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     900             # If input is 1D raise error
#     901             if array.ndim == 1:
# --> 902                 raise ValueError(
#     903                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     904                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[1714 1664 1760 1685 1693 1670 1764 1764 1792 1850 1735 1775 1735 1712
#  1773 1872 1755 1674 1842 1786 1761 1722 1663 1687 1974 1826 1787 1821
#  2020 1794 1769 1934 1775 1855 1880 1849 1808 1954 1777 1831 1865 1850
#  1966 1702 1990 1925 1824 1956 1857 1979 1802 1855 1907 1634 1879 1887
#  1730 1953 1781 1891 1964 1808 1893 2041 1893 1832 1850 1934 1861 1931
#  1933 1778 1975 1934 2021 2015 1997 2020 1843 1936 1810 1987 1962 2050].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)

data.hist()
correlation = data.corr()
print(correlation)
X=data.drop(data.columns[[0,2]],axis=1)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']), y=data['mpg'])
print('gia tri Intercept la:',model.intercept_)
print('gia tri Coeffient la:',model.coef_)
model.score(pd.DataFrame(data['wt']),data['mpg'])

data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black')
y_pred=model.predict(pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_pred,color='red')
# Out:
# gia tri Intercept la: 37.28512616734204
# gia tri Coeffient la: [-5.34447157]
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# Out:
# gia tri Intercept la: 37.28512616734204
# gia tri Coeffient la: [-5.34447157]
# 0.7528327936582646

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Intercept:[c] cua mo hinh bac 2:')
print(model.intercept_)
print('Coeffient:[b a] cua mo hinh bac 2:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# Intercept:[c] cua mo hinh bac 2:
# 49.93081094945181
# Coeffient:[b a] cua mo hinh bac 2:
# [-13.38033708   1.17108689]
# do chinh xac cua mo hinh
# 0.8190613581384094

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 3:')
print(model.intercept_)
print('coeffient cua mo hinh bac 3:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# intercept cua mo hinh bac 3:
# 48.40369622795221
# coeffient cua mo hinh bac 3:
# [-11.82597602   0.68937919   0.04593618]
# do chinh xac cua mo hinh
# 0.8191284628478992

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 4:')
print(model.intercept_)
print('coeffient cua mo hinh bac 4:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# intercept cua mo hinh bac 4:
# 14.455833054796258
# coeffient cua mo hinh bac 4:
# [ 36.61945631 -23.70175729   5.20042113  -0.38627878]
# do chinh xac cua mo hinh
# 0.8219709873435187

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 5:')
print(model.intercept_)
print('coeffient cua mo hinh bac 5:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 5:
# -87.71816314301019
# coeffient cua mo hinh bac 5:
# [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# do chinh xac cua mo hinh
# 0.8251088272653132
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']

model=linear_model.LinearRegression()

X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 6:')
print(model.intercept_)
print('coeffient cua mo hinh bac 6:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 6:
# -580.1180291191426
# coeffient cua mo hinh bac 6:
# [ 1.25251793e+03 -1.01544961e+03  4.19153811e+02 -9.38894251e+01
#   1.08661013e+01 -5.09042883e-01]
# do chinh xac cua mo hinh
# 0.8322482465599783
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']

model=linear_model.LinearRegression()

X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 7:')
print(model.intercept_)
print('coeffient cua mo hinh bac 7:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 7:
# -2387.286256135588
# coeffient cua mo hinh bac 7:
# [ 5.71347281e+03 -5.57680321e+03  2.92547757e+03 -8.93984147e+02
#   1.59440329e+02 -1.53893379e+01  6.21028572e-01]
# do chinh xac cua mo hinh
# 0.8380739929060077
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
h=0
model=linear_model.LinearRegression()

X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 8:')
print(model.intercept_)
print('coeffient cua mo hinh bac 8:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7,range**8]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 8:
# 1582.7973359661294
# coeffient cua mo hinh bac 8:
# [-5.64544414e+03  8.25196062e+03 -6.43425547e+03  2.96002820e+03
#  -8.29805697e+02  1.39294521e+02 -1.28609866e+01  5.01914523e-01]
# do chinh xac cua mo hinh
# 0.8402829929877587
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
h=0
model=linear_model.LinearRegression()

X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 9:')
print(model.intercept_)
print('coeffient cua mo hinh bac 9:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 9:
# 38889.610890257565
# coeffient cua mo hinh bac 9:
# [-1.25317627e+05  1.74784059e+05 -1.38423294e+05  6.86522656e+04
#  -2.21343938e+04  4.64432999e+03 -6.12230173e+02  4.60606389e+01
#  -1.50849985e+00]
# do chinh xac cua mo hinh
# 0.8646786785489688
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()

X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 10:')
print(model.intercept_)
print('coeffient cua mo hinh bac 10:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# intercept cua mo hinh bac 10:
# -14921.11995188375
# coeffient cua mo hinh bac 10:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# do chinh xac cua mo hinh
# 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['wt'], data['wt']**2, data['wt']**3, data['wt']**4,data['wt']**5,data['wt']**6,data['wt']**7,data['wt']**8,data['wt']**9,data['wt']**10,data['wt']**11,data['wt']**12,data['wt']**13,data['wt']**14,data['wt']**15]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh bac 15:')
print(model.intercept_)
print('coeffient cua mo hinh bac 15:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# intercept cua mo hinh bac 15:
# -1183.775900530815
# coeffient cua mo hinh bac 15:
# [ 1.15482832e+03  8.26985531e+02 -3.77299068e+02 -9.90227356e+02
#  -8.54738725e+01  1.01497570e+03  5.84542984e+01 -1.14654333e+03
#   1.05398762e+03 -4.97390219e+02  1.43996618e+02 -2.66141482e+01
#   3.07575388e+00 -2.03158530e-01  5.86600122e-03]
# do chinh xac cua mo hinh
# 0.8793156609915943

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/mtcars.csv'
data = pd.read_csv(url)

range = np.arange(1.5,5.5,0.1)
predictor = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10,range**11,range**12,range**13,range**14,range**15]).T
y_pred = model.predict(X=predictor)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/50_Startups.csv'
data = pd.read_csv(url)
data.head()

sns.pairplot(data)

corr=data.corr()
sns.heatmap(corr,annot=True)

X=data.drop('Profit',axis=True)
X=data.drop('State',axis=True)
y = data['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/50_Startups.csv'
data = pd.read_csv(url)
y=data['Profit']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'],data['R&D Spend']**2]).T
model.fit(X,y=data['Profit'])
print('intercept cua mo hinh bac 1:')
print(model.intercept_)
print('coeffient cua mo hinh bac 1:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# intercept cua mo hinh bac 1:
# 48128.14916956878
# coeffient cua mo hinh bac 1:
# [ 8.90147291e-01 -2.31821806e-07]
# do chinh xac cua mo hinh
# 0.946703652909133

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/50_Startups.csv'
data = pd.read_csv(url)
y=data['Profit']
range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X_range)
data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9), color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/50_Startups.csv'
data = pd.read_csv(url)
y=data['Profit']
model=linear_model.LinearRegression()
X = pd.DataFrame([data['R&D Spend'], data['R&D Spend']**2, data['R&D Spend']**3, data['R&D Spend']**4,data['R&D Spend']**5,data['R&D Spend']**6,data['R&D Spend']**7,data['R&D Spend']**8,data['R&D Spend']**9,data['R&D Spend']**10]).T
model.fit(X,y=data['Profit'])
print('intercept cua mo hinh bac 10:')
print(model.intercept_)
print('coeffient cua mo hinh bac 10:')
print(model.coef_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
# Out:
# intercept cua mo hinh bac 10:
# 88222.34536583656
# coeffient cua mo hinh bac 10:
# [ 5.51258424e-70 -2.84081425e-39  1.36361271e-45  3.26751007e-66
#   7.14930577e-50  6.00188335e-45  4.22025487e-40  1.99075980e-35
#  -2.43124781e-40  7.49857982e-46]
# do chinh xac cua mo hinh
# 0.7054994430986499

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model

url='/content/50_Startups.csv'
data = pd.read_csv(url)

range = np.arange(1.5,5.5,0.1)
X_range = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred = model.predict(X_range)
data.plot(kind='scatter',x='R&D Spend',y='Profit',figsize=(9,9), color='black',xlim=(0,10))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/mtcars.csv'
data = pd.read_csv(url)
X=data.loc[:,['wt','hp']]
y=data['mpg']
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp']],y=data['mpg'])
print('coeffient', model.coef_)
print('intercept',model.intercept_)
print('do chinh xac cua mo hinh')
print(model.score(X,y))
print('chinh xac',X,y)
# Out:
# coeffient [-3.87783074 -0.03177295]
# intercept 37.227270116447215
# do chinh xac cua mo hinh
# 0.8267854518827914
# chinh xac        wt   hp
# 0   2.620  110
# 1   2.875  110
# 2   2.320   93
# 3   3.215  110
# 4   3.440  175
# 5   3.460  105
# 6   3.570  245
# 7   3.190   62
# 8   3.150   95
# 9   3.440  123
# 10  3.440  123
# 11  4.070  180
# 12  3.730  180
# 13  3.780  180
# 14  5.250  205
# 15  5.424  215
# 16  5.345  230
# 17  2.200   66
# 18  1.615   52
# 19  1.835   65
# 20  2.465   97
# 21  3.520  150
# 22  3.435  150
# 23  3.840  245
# 24  3.845  175
# 25  1.935   66
# 26  2.140   91
# 27  1.513  113
# 28  3.170  264
# 29  2.770  175
# 30  3.570  335
# 31  2.780  109 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/mtcars.csv'
data = pd.read_csv(url)
y=data['mpg']
X=data.loc[:,['wt','hp','disp']]
model = linear_model.LinearRegression()
model.fit(X=data.loc[:,['wt','hp','disp']],y=data['mpg'])
print('coeffient', model.coef_)
print('intercept',model.intercept_)
print('do chinh xac')
print(X,y)
# Out:
# coeffient [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
# intercept 37.10550526903184
# do chinh xac
#        wt   hp   disp
# 0   2.620  110  160.0
# 1   2.875  110  160.0
# 2   2.320   93  108.0
# 3   3.215  110  258.0
# 4   3.440  175  360.0
# 5   3.460  105  225.0
# 6   3.570  245  360.0
# 7   3.190   62  146.7
# 8   3.150   95  140.8
# 9   3.440  123  167.6
# 10  3.440  123  167.6
# 11  4.070  180  275.8
# 12  3.730  180  275.8
# 13  3.780  180  275.8
# 14  5.250  205  472.0
# 15  5.424  215  460.0
# 16  5.345  230  440.0
# 17  2.200   66   78.7
# 18  1.615   52   75.7
# 19  1.835   65   71.1
# 20  2.465   97  120.1
# 21  3.520  150  318.0
# 22  3.435  150  304.0
# 23  3.840  245  350.0
# 24  3.845  175  400.0
# 25  1.935   66   79.0
# 26  2.140   91  120.3
# 27  1.513  113   95.1
# 28  3.170  264  351.0
# 29  2.770  175  145.0
# 30  3.570  335  301.0
# 31  2.780  109  121.0 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (10,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
calculation=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
print(regressor.score(X_train,y_train))
print(regressor.score(X_test,y_test))
# Out:
# 1.0
# 1.0

# %%
#advertising
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/Advertising.csv'
data1 = pd.read_csv(url)
data1.head()

sns.pairplot(data1)

# %%
data1 = pd.read_csv(url)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url='/content/Advertising.csv'

y=data1['sales']
model=linear_model.LinearRegression()
X = pd.DataFrame([data1['TV'],data1['TV']**2,data1['TV']**3,data1['TV']**4,data1['TV']**5,data1['TV']**6]).T
model.fit(X,y=data1['sales'])
range = np.arange(1.5,300.5,0.1)
A = pd.DataFrame([range, range**2,range**3,range**4,range**5,range**6]).T
y_pred = model.predict(A)
data1.plot(kind='scatter',x='TV',y='sales',figsize=(9,9), color='black')
plt.plot(range,y_pred,color='blue')
print(model.score(X,y))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# 0.629177812047104

# %%
X=data1.drop('radio',axis=True)
X=data1.drop('newspaper',axis=True)
y = data1['sales']
     

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
     

from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (40,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
calculation=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original sales','Predicted sales'])
print(regressor.score(X_train,y_train))
print(regressor.score(X_test,y_test))
# Out:
# 1.0
# 1.0
