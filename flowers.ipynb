# %% [markdown]
# <a href="https://colab.research.google.com/github/Pipo0603/ExerciseAI/blob/main/flowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras import preprocessing
from tensorflow.keras.utils import load_img, img_to_array

# %%
data="/content/drive/MyDrive/Hoa/"

# %%
print("Bắt đầu xử lý ảnh...")

pixels,labels=list(),list()

for folder in listdir(data):
    if folder!='.DS_Store':
        #print("Folder=",folder)
        for file in listdir(data  + folder):
            if file!='.DS_Store':
                #print("File=", file)
                pixel=load_img(data  + folder +"/" + file,target_size=(280,180))
                pixel=img_to_array(pixel)
                pixels.append(pixel)
                labels.append( folder)

pixels =asarray(pixels)
labels =asarray(labels)#.reshape(-1,1)
# Out:
# Bắt đầu xử lý ảnh...

# %%
from sklearn.preprocessing import LabelBinarizer
import pickle
from sklearn.model_selection import train_test_split
encoder = LabelBinarizer()
labels = encoder.fit_transform(labels)
#print(labels)

file = open('pix.data', 'wb')
# dump information to that file
pickle.dump((pixels,labels), file)
# close the file
file.close()

# %%
def load_data():
    file = open('pix.data', 'rb')
    # dump information to that file
    (pixels, labels) = pickle.load(file)
    # close the file
    file.close()
    return pixels, labels

#save_data()
X,y = load_data()
#random.shuffle(X)
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (39, 280, 180, 3)
# (10, 280, 180, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense
from numpy.ma.core import reshape

# %%
X_train= X_train.astype('float32')/255
print(y_train.shape)
X_test= X_test.astype('float32')/255
# Out:
# (39, 5)

# %%
from keras import models 
from keras.models import Sequential,Model
from keras import Input
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization
from keras.optimizers import Adam
batch_size=100 #lô
epochs=20     #số lần học
classes=5    #phân loại

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(280,180,3),padding='same'))
from keras.layers import LeakyReLU
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))
#so lan tich chap
model.add(Conv2D(64,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

# %%
from keras import optimizers
from keras import losses
model.add(Flatten())
model.add(Dense(1000,activation='linear'))
model.add(Dense(500,activation='linear'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(classes,activation='softmax'))
model.compile(loss=losses.categorical_crossentropy,optimizer=Adam(),metrics=['accuracy'])
model.summary()
train=model.fit(X_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 280, 180, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 280, 180, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 140, 90, 32)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 140, 90, 64)       18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 140, 90, 64)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 70, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 70, 45, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 70, 45, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 35, 23, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 103040)            0
#
#  dense (Dense)               (None, 1000)              103041000
#
#  dense_1 (Dense)             (None, 500)               500500
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 500)               0
#
#  dense_2 (Dense)             (None, 5)                 2505
#
# =================================================================
# Total params: 103,637,253
# Trainable params: 103,637,253
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1/1 [==============================] - 11s 11s/step - loss: 1.6292 - accuracy: 0.1795
# Epoch 2/20
# 1/1 [==============================] - 0s 101ms/step - loss: 22.0320 - accuracy: 0.1795
# Epoch 3/20
# 1/1 [==============================] - 0s 106ms/step - loss: 33.7481 - accuracy: 0.2308
# Epoch 4/20
# 1/1 [==============================] - 0s 121ms/step - loss: 13.3444 - accuracy: 0.4615
# Epoch 5/20
# 1/1 [==============================] - 0s 119ms/step - loss: 7.8375 - accuracy: 0.3590
# Epoch 6/20
# 1/1 [==============================] - 0s 114ms/step - loss: 8.1596 - accuracy: 0.1795
# Epoch 7/20
# 1/1 [==============================] - 0s 110ms/step - loss: 2.2193 - accuracy: 0.3846
# Epoch 8/20
# 1/1 [==============================] - 0s 114ms/step - loss: 1.3453 - accuracy: 0.6410
# Epoch 9/20
# 1/1 [==============================] - 0s 110ms/step - loss: 1.3100 - accuracy: 0.6154
# Epoch 10/20
# 1/1 [==============================] - 0s 118ms/step - loss: 1.1730 - accuracy: 0.6923
# Epoch 11/20
# 1/1 [==============================] - 0s 99ms/step - loss: 2.0577 - accuracy: 0.4615
# Epoch 12/20
# 1/1 [==============================] - 0s 121ms/step - loss: 0.8057 - accuracy: 0.6154
# Epoch 13/20
# 1/1 [==============================] - 0s 119ms/step - loss: 0.6850 - accuracy: 0.8462
# Epoch 14/20
# 1/1 [==============================] - 0s 136ms/step - loss: 0.8071 - accuracy: 0.6667
# Epoch 15/20
# 1/1 [==============================] - 0s 103ms/step - loss: 0.7178 - accuracy: 0.7179
# Epoch 16/20
# 1/1 [==============================] - 0s 134ms/step - loss: 0.4433 - accuracy: 0.9744
# Epoch 17/20
# 1/1 [==============================] - 0s 110ms/step - loss: 0.4231 - accuracy: 0.8718
# Epoch 18/20
# 1/1 [==============================] - 0s 104ms/step - loss: 0.3630 - accuracy: 0.8462
# Epoch 19/20
# 1/1 [==============================] - 0s 100ms/step - loss: 0.2525 - accuracy: 0.9487
# Epoch 20/20
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1611 - accuracy: 1.0000

# %%
model.save("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_hoa.h5")

# %%
from keras.saving.saving_lib import load_model
import matplotlib.pyplot as plt
from keras.models import load_model
model100=load_model("/content/drive/MyDrive/Colab Notebooks/BT/nhan_dien_hoa.h5")
img=load_img('/content/drive/MyDrive/Hoa/Daisy/Daisy_2.jpg')
plt.imshow(img)
plt.show()

# %%
img = load_img('/content/drive/MyDrive/Hoa/Daisy/Daisy_2.jpg',target_size=(280,180))
plt.imshow(img)

# %%
import numpy as np
class_name = ['Apricot','Daisy','Lotus','Rose','Water lily']
img=img_to_array(img)
img=img.reshape(1,280,180,3)
img=img.astype('float32')
img=img/255
predict = model100.predict(img)
print("ĐÂY LÀ HOA: ", class_name[np.argmax(predict[0])], (predict[0]))
print(np.max(predict[0],axis=0))
# Out:
# 1/1 [==============================] - 0s 114ms/step
# ĐÂY LÀ HOA:  Daisy [0.02119297 0.9286066  0.00920657 0.00708184 0.03391194]
# 0.9286066
